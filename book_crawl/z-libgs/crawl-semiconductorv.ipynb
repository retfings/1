# %%
from bs4 import BeautifulSoup
import requests
from copy import deepcopy
import csv
import random

# %%
res = requests.get("https://z-lib.gs/s/半导体")

# %%
soup =  BeautifulSoup(res.text,'html.parser')

# %%
divs = soup.find_all("div",{'class':'book-item'})

# %%
for div in divs:
    print(div)
# Out:
# <div class="book-item resItemBoxBooks exactMatch">
# <div class="counter">1</div>
# <z-bookcard contenttypeparam="?content_type=book" extension="pdf" filesize="82.35 MB" href="/book/12066614/64423b/%E5%8D%8A%E5%AF%BC%E4%BD%93%E7%89%A9%E7%90%86%E5%AD%A6-%E5%88%98%E6%81%A9%E7%A7%91-%E7%AC%AC%E4%B8%83%E7%89%88.html" id="12066614" isbn="" language="chinese" publisher="电子工业出版社" quality="5.0" rating="5.0" termshash="" year="0">
# <img data-src="https://s3proxy.cdn-zlib.sk/covers100/collections/userbooks/91ef6b723bdd2fa91bdff2091c7e6b74b0b012eedc209b127e6e2c4b16b45e27.png">
# <div slot="title">半导体物理学 刘恩科 第七版</div>
# <div slot="author">刘恩科</div>
# <div slot="note"></div>
# <div slot="extend">
# </div>
# </img></z-bookcard>
# </div>
# <div class="book-item resItemBoxBooks exactMatch">
# <div class="counter">2</div>
# ...

# %%
title = div.find('div',{'slot':'title'})
# Out:
# <div class="book-item resItemBoxBooks exactMatch">
# <div class="counter">50</div>
# <z-bookcard contenttypeparam="?content_type=book" extension="epub" filesize="139.58 MB" href="/book/17816941/b41b6d/%E6%A8%A1%E6%8B%9F%E7%94%B5%E5%AD%90%E7%B3%BB%E7%BB%9F%E8%AE%BE%E8%AE%A1%E6%8C%87%E5%8D%97%E5%9F%BA%E7%A1%80%E7%AF%87%E4%BB%8E%E5%8D%8A%E5%AF%BC%E4%BD%93%E5%88%86%E7%AB%8B%E5%85%83%E4%BB%B6%E5%88%B0ti%E9%9B%86%E6%88%90%E7%94%B5%E8%B7%AF%E7%9A%84%E5%88%86%E6%9E%90%E4%B8%8E%E5%AE%9E%E7%8E%B0.html" id="17816941" isbn="B07BSJ5Z2R" language="chinese" publisher="电子工业出版社" quality="0.0" rating="5.0" termshash="f69f1cfbaaae674acb97e47ad46eef5a" year="2017">
# <img data-src="https://s3proxy.cdn-zlib.sk/covers100/collections/userbooks/c06706bccf969c407081d0aaf4b89f9c9d47587e746db26cc58c3a4fd21a2ef2.jpg"/>
# <div slot="title">模拟电子系统设计指南（基础篇）：从半导体、分立元件到TI集成电路的分析与实现</div>
# <div slot="author">何宾</div>
# <div slot="note"></div>
# <div slot="extend">
# </div>
# </z-bookcard>
# </div>
